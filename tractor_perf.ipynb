# %%
''' An example of learning a Deep-Q Agent on Tractor
'''

def run():
    import tensorflow as tf
    import os

    from tqdm import tqdm, trange

    import rlcard
    from rlcard.agents import DQNAgent
    from rlcard.agents import RandomAgent, TractorRuleAgent
    from rlcard.utils import set_global_seed, tournament
    from rlcard.utils import Logger
    from rlcard.games.tractor.utils import tournament_tractor, MovingAvg, ACTION_LIST

    # Set a global seed
    set_global_seed(0)

    # Make environment
    env = rlcard.make('tractor', config={'seed': 0})
    eval_env = rlcard.make('tractor', config={'seed': 0})

    # Set the iterations numbers and how frequently we evaluate the performance
    evaluate_every = 2000
    evaluate_num = 1000
    # episode_num = 100000
    episode_num = 10000

    # The intial memory size
    memory_init_size = 1000

    # Train the agent every X steps
    train_every = 64

    # The paths for saving the logs and learning curves
    log_dir = './experiments/tractor_dqn_result/'

    # Mitigation for gpu memory issue
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True

    agents = []

    with tf.Session(config=config) as sess:
    # with tf.Session() as sess:

        # Initialize a global step
        global_step = tf.Variable(0, name='global_step', trainable=False)

        # Set up the agents
        for i in range(1):
            agent = DQNAgent(sess,
                            scope='dqn' if i==0 else 'dqn' + str(i),
                            action_num=env.action_num,
                            replay_memory_init_size=memory_init_size,
                            train_every=train_every,
                            state_shape=env.state_shape,
                            mlp_layers=[2048,2048],
                            replay_memory_size=100000,
                            update_target_estimator_every=500,
                            discount_factor=0.5,
                            epsilon_start=1,
                            epsilon_end=0.1,
                            epsilon_decay_steps=100000,
                            # epsilon_decay_steps=400000,
                            batch_size=256,
                            learning_rate=0.00002,
                            use_rule_policy=False
                        )
            agents.append(agent)
        
        random_agent = RandomAgent(action_num=eval_env.action_num)
        rule_agent = TractorRuleAgent(action_num=eval_env.action_num)

        # 1 dqn agent vs 3 rule agent
        # env.set_agents([agent, rule_agent, rule_agent, rule_agent])
        # eval_env.set_agents([agent, rule_agent, rule_agent, rule_agent])

        # 2 dqn agent vs 2 random agent
        # env.set_agents([agent, random_agent, agent, random_agent])
        # eval_env.set_agents([agent, random_agent, agent, random_agent])

        # 2 dqn agent vs 2 rule agent
        # env.set_agents([agent, rule_agent, agent, rule_agent])
        # eval_env.set_agents([agent, rule_agent, agent, rule_agent])

        # # 4 dqn agent with single brain
        env.set_agents([agents[0], agents[0], agents[0], agents[0]])
        eval_env.set_agents([agents[0], rule_agent, agents[0], rule_agent])

        # 4 dqn agent with two brains
        # env.set_agents([agents[0], agents[1], agents[0], agents[1]])
        # eval_env.set_agents([agents[0], rule_agent, agents[0], rule_agent])

        # Initialize global variables
        sess.run(tf.global_variables_initializer())

        # Init a Logger to plot the learning curve
        logger = Logger(log_dir)

        # Init moving average calculator
        m_avg = MovingAvg(100)
        payoff_avg = MovingAvg(100)

        # Store a test state to track Q value
        # state, player_id = env.reset()
        # predefined_hands = [['TD', 'AD'],
        #                     ['KS', 'AS'],
        #                     ['TD', '3D'],
        #                     ['3D', '4D']]
        # state = env.reset_predefine_state(predefined_hands)
        # for i in range(4):
        #     print(env.game.players[i].current_hand)

        
        t = trange(episode_num, desc='rl-loss:', leave=True)
        for episode in t:
            # Generate data from the environment
            trajectories, payoffs = env.run(is_training=True)
            payoff_avg.append(payoffs[0])

            # Feed transitions into agent memory, and train the agent
            for player in [0, 1, 2, 3]:
                for ts in trajectories[player]:
                    rl_loss = env.agents[player].feed(ts)
                    if rl_loss != None:
                        m_avg.append(rl_loss)

            t.set_description("rl loss: {}, payoff: {}, epsilon: {}".format(
                round(m_avg.get(), 2), 
                round(payoff_avg.get(), 2), 
                round(agent.epsilons[min(agent.total_t, agent.epsilon_decay_steps-1)], 2)
                ), refresh=True)

            # q = env.agents[0].eval_step(state)[1]
            # probs = {ACTION_LIST[i]:round(q[i],3) for i in range(len(q)) if q[i] != -100}
            # probs = sorted(probs.items(), key=lambda x: x[1], reverse=True)
            # tqdm.write(str(probs))

            # Evaluate the performance. Play with random agents.
            if episode % evaluate_every == evaluate_every - 1:
                logger.log_performance(env.timestep, tournament_tractor(eval_env, evaluate_num)[0])

        # Close files in the logger
        logger.close_files()

        # Plot the learning curve
        logger.plot('DQN')
        
        # Save model
        save_dir = 'models/tractor_dqn'
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        saver = tf.train.Saver()
        saver.save(sess, os.path.join(save_dir, 'model'))
        

from tqdm import tqdm
from rlcard.games.tractor import Game
import cProfile

cProfile.run('run()')
# Out:
# WARNING:tensorflow:From d:\Projects\rlcard\rlcard\utils\utils.py:335: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From d:\Projects\rlcard\rlcard\agents\dqn_agent.py:269: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From d:\Projects\rlcard\rlcard\agents\dqn_agent.py:286: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From C:\Users\RanW\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\RanW\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From d:\Projects\rlcard\rlcard\agents\dqn_agent.py:311: The name tf.squared_difference is deprecated. Please use tf.math.squared_difference instead.
#
# WARNING:tensorflow:From d:\Projects\rlcard\rlcard\agents\dqn_agent.py:272: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From d:\Projects\rlcard\rlcard\agents\dqn_agent.py:272: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From d:\Projects\rlcard\rlcard\agents\dqn_agent.py:272: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From d:\Projects\rlcard\rlcard\agents\dqn_agent.py:274: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From d:\Projects\rlcard\rlcard\agents\dqn_agent.py:277: get_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_global_step
# rl loss: 0.0, payoff: 104.0, epsilon: 0.99:   0%|          | 10/10000 [00:01<28:31,  5.84it/s]WARNING:tensorflow:From d:\Projects\rlcard\rlcard\agents\dqn_agent.py:395: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# rl loss: 875.04, payoff: 103.18, epsilon: 0.99:   0%|          | 11/10000 [00:02<34:17,  4.85it/s]
# INFO - Copied model parameters to target network.
# rl loss: 692.03, payoff: 109.9, epsilon: 0.8:   2%|▏         | 240/10000 [00:50<34:27,  4.72it/s]
#          23714719 function calls (23395843 primitive calls) in 56.775 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#       333    0.001    0.000    0.029    0.000 <__array_function__ internals>:2(argmax)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#    210183    0.151    0.000    0.398    0.000 <__array_function__ internals>:2(copyto)
#     22287    0.025    0.000    0.406    0.000 <__array_function__ internals>:2(expand_dims)
#         1    0.000    0.000    0.001    0.001 <__array_function__ internals>:2(linspace)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#        48    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(prod)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#     22286    0.038    0.000    0.421    0.000 <__array_function__ internals>:2(sum)
# 31163/771    0.015    0.000    2.534    0.003 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#      5601    0.009    0.000    0.009    0.000 <frozen importlib._bootstrap>:103(release)
#      3106    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:143(__init__)
#      3106    0.003    0.000    0.034    0.000 <frozen importlib._bootstrap>:147(__enter__)
#      3106    0.002    0.000    0.009    0.000 <frozen importlib._bootstrap>:151(__exit__)
#      5601    0.012    0.000    0.031    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#      3137    0.004    0.000    0.005    0.000 <frozen importlib._bootstrap>:176(cb)
#      2495    0.003    0.000    0.015    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#    4180/4    0.002    0.000    3.360    0.840 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#     17922    0.006    0.000    0.006    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#      2475    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:307(__init__)
#      2475    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap>:311(__enter__)
#      2475    0.005    0.000    0.010    0.000 <frozen importlib._bootstrap>:318(__exit__)
#      9898    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#      2444    0.003    0.000    0.003    0.000 <frozen importlib._bootstrap>:35(_new_module)
#      2898    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap>:369(__init__)
#        40    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:391(__eq__)
#      4918    0.003    0.000    0.033    0.000 <frozen importlib._bootstrap>:403(cached)
#      3341    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:416(parent)
#      2475    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:433(spec_from_loader)
#      2475    0.011    0.000    0.054    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
# 2475/2471    0.004    0.000    0.143    0.000 <frozen importlib._bootstrap>:576(module_from_spec)
#      3137    0.004    0.000    0.017    0.000 <frozen importlib._bootstrap>:58(__init__)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:634(_load_backward_compatible)
#    2482/4    0.010    0.000    3.364    0.841 <frozen importlib._bootstrap>:663(_load_unlocked)
#         1    0.000    0.000    0.060    0.060 <frozen importlib._bootstrap>:686(_load)
#      2887    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:719(find_spec)
#      5601    0.010    0.000    0.011    0.000 <frozen importlib._bootstrap>:78(acquire)
#      2887    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap>:792(find_spec)
#      9105    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:855(__enter__)
#      9105    0.003    0.000    0.004    0.000 <frozen importlib._bootstrap>:859(__exit__)
#       444    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:873(_find_spec_legacy)
#      2887    0.017    0.000    0.565    0.000 <frozen importlib._bootstrap>:882(_find_spec)
#        88    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:929(_sanity_check)
#    3024/4    0.010    0.000    3.367    0.842 <frozen importlib._bootstrap>:948(_find_and_load_unlocked)
#   3105/11    0.022    0.000    3.367    0.306 <frozen importlib._bootstrap>:978(_find_and_load)
#     88/11    0.000    0.000    2.004    0.182 <frozen importlib._bootstrap>:994(_gcd_import)
#        31    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1029(__init__)
#     31/30    0.000    0.000    0.082    0.003 <frozen importlib._bootstrap_external>:1040(create_module)
#     31/19    0.000    0.000    0.045    0.002 <frozen importlib._bootstrap_external>:1048(exec_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1087(_find_parent_path_names)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1097(_get_parent_path)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1101(_recalculate)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1114(__iter__)
#       459    0.027    0.000    0.051    0.000 <frozen importlib._bootstrap_external>:1190(_path_hooks)
#      3667    0.003    0.000    0.054    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
# 2888/2887    0.009    0.000    0.535    0.000 <frozen importlib._bootstrap_external>:1240(_get_spec)
#      2887    0.002    0.000    0.537    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#       459    0.002    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:1319(__init__)
#      3672    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1325(<genexpr>)
#      2474    0.004    0.000    0.014    0.000 <frozen importlib._bootstrap_external>:1351(_get_spec)
#      3607    0.028    0.000    0.469    0.000 <frozen importlib._bootstrap_external>:1356(find_spec)
#       459    0.005    0.000    0.047    0.000 <frozen importlib._bootstrap_external>:1404(_fill_cache)
#       459    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1433(<setcomp>)
#       459    0.001    0.000    0.024    0.000 <frozen importlib._bootstrap_external>:1445(path_hook_for_FileFinder)
#      4888    0.015    0.000    0.043    0.000 <frozen importlib._bootstrap_external>:271(cache_from_source)
#      3607    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:36(_relax_case)
#      2474    0.004    0.000    0.030    0.000 <frozen importlib._bootstrap_external>:369(_get_cached)
# 2446/2445    0.003    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:401(_check_name_wrapper)
#      2444    0.006    0.000    0.009    0.000 <frozen importlib._bootstrap_external>:438(_classify_pyc)
#      2444    0.003    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:471(_validate_timestamp_pyc)
#      7332    0.003    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:51(_r_long)
#      2444    0.006    0.000    0.185    0.000 <frozen importlib._bootstrap_external>:523(_compile_bytecode)
#     18778    0.013    0.000    0.034    0.000 <frozen importlib._bootstrap_external>:56(_path_join)
#      2474    0.006    0.000    0.009    0.000 <frozen importlib._bootstrap_external>:574(spec_from_file_location)
#     18778    0.012    0.000    0.016    0.000 <frozen importlib._bootstrap_external>:58(<listcomp>)
#      4891    0.012    0.000    0.015    0.000 <frozen importlib._bootstrap_external>:62(_path_split)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:711(is_package)
#      2444    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:719(create_module)
#    2444/4    0.007    0.000    3.363    0.841 <frozen importlib._bootstrap_external>:722(exec_module)
#     10687    0.006    0.000    0.463    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#      2444    0.056    0.000    1.028    0.000 <frozen importlib._bootstrap_external>:793(get_code)
#      4636    0.005    0.000    0.198    0.000 <frozen importlib._bootstrap_external>:84(_path_is_mode_type)
#      2444    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:884(__init__)
#        40    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:890(__eq__)
#      2445    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:909(get_filename)
#      2444    0.549    0.000    0.647    0.000 <frozen importlib._bootstrap_external>:914(get_data)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:921(get_resource_reader)
#      4175    0.002    0.000    0.181    0.000 <frozen importlib._bootstrap_external>:93(_path_isfile)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:931(resource_path)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:937(is_resource)
#      2444    0.003    0.000    0.103    0.000 <frozen importlib._bootstrap_external>:951(path_stats)
#       461    0.000    0.000    0.019    0.000 <frozen importlib._bootstrap_external>:98(_path_isdir)
#         1    0.026    0.026   56.809   56.809 <ipython-input-1-7f0ffaa72166>:4(run)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#        12    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         1    0.000    0.000    0.000    0.000 <string>:134(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:139(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:174(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:2(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:207(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:263(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:278(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:306(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:307(_InitOpDefLibrary)
#         1    0.000    0.000    0.001    0.001 <string>:4(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:411(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:441(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:478(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:79(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:806(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 <string>:975(_InitOpDefLibrary)
#         1    0.000    0.000    0.000    0.000 ElementPath.py:255(_SelectorContext)
#         1    0.000    0.000    0.001    0.001 ElementPath.py:59(<module>)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:105(ParseError)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:1139(_ListDataStream)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:124(Element)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:1249(XMLPullParser)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:1361(TreeBuilder)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:1437(XMLParser)
#         1    0.000    0.000    0.003    0.003 ElementTree.py:34(<module>)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:495(QName)
#         1    0.000    0.000    0.000    0.000 ElementTree.py:543(ElementTree)
#         1    0.000    0.000    0.000    0.000 Image.py:2557(ImagePointHandler)
#         1    0.000    0.000    0.000    0.000 Image.py:2566(ImageTransformHandler)
#         1    0.000    0.000    0.010    0.010 Image.py:27(<module>)
#         1    0.000    0.000    0.000    0.000 Image.py:3258(_apply_env_variables)
#         1    0.000    0.000    0.000    0.000 Image.py:3294(Exif)
#         1    0.000    0.000    0.000    0.000 Image.py:462(_E)
#         1    0.000    0.000    0.000    0.000 Image.py:503(Image)
#         1    0.000    0.000    0.000    0.000 Image.py:91(DecompressionBombWarning)
#         1    0.000    0.000    0.000    0.000 Image.py:95(DecompressionBombError)
#         1    0.000    0.000    0.012    0.012 ImageEnhance.py:21(<module>)
#         1    0.000    0.000    0.000    0.000 ImageEnhance.py:24(_Enhance)
#         1    0.000    0.000    0.000    0.000 ImageEnhance.py:39(Color)
#         1    0.000    0.000    0.000    0.000 ImageEnhance.py:57(Contrast)
#         1    0.000    0.000    0.000    0.000 ImageEnhance.py:74(Brightness)
#         1    0.000    0.000    0.000    0.000 ImageEnhance.py:90(Sharpness)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:103(MinFilter)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:118(MaxFilter)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:133(ModeFilter)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:151(GaussianBlur)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:166(BoxBlur)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:17(<module>)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:187(UnsharpMask)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:20(Filter)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:213(BLUR)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:226(CONTOUR)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:237(DETAIL)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:24(MultibandFilter)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:248(EDGE_ENHANCE)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:259(EDGE_ENHANCE_MORE)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:270(EMBOSS)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:28(BuiltinFilter)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:281(FIND_EDGES)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:292(SHARPEN)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:303(SMOOTH)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:314(SMOOTH_MORE)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:327(Color3DLUT)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:35(Kernel)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:64(RankFilter)
#         1    0.000    0.000    0.000    0.000 ImageFilter.py:88(MedianFilter)
#         1    0.000    0.000    0.000    0.000 ImageMode.py:17(<module>)
#         1    0.000    0.000    0.000    0.000 ImageMode.py:20(ModeDescriptor)
#         1    0.000    0.000    0.000    0.000 ImageStat.py:24(<module>)
#         1    0.000    0.000    0.000    0.000 ImageStat.py:29(Stat)
#         1    0.000    0.000    0.000    0.000 TiffTags.py:20(<module>)
#         1    0.000    0.000    0.000    0.000 TiffTags.py:23(TagInfo)
#       105    0.000    0.000    0.000    0.000 TiffTags.py:26(__new__)
#         1    0.000    0.000    0.000    0.000 TiffTags.py:361(_populate)
#       227    0.000    0.000    0.847    0.004 __init__.py:1(<module>)
#         4    0.000    0.000    0.005    0.001 __init__.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1000(PythonFormatter)
#        13    0.000    0.000    0.006    0.000 __init__.py:1002(flush)
#         1    0.000    0.000    0.013    0.013 __init__.py:101(<module>)
#        13    0.000    0.000    0.008    0.001 __init__.py:1013(emit)
#         1    0.000    0.000    0.000    0.000 __init__.py:1022(ABSLLogger)
#         1    0.000    0.000    0.057    0.057 __init__.py:109(<module>)
#     88/11    0.000    0.000    2.005    0.182 __init__.py:109(import_module)
#         3    0.000    0.000    0.000    0.000 __init__.py:11(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:11(set_keras_submodules)
#         3    0.000    0.000    0.000    0.000 __init__.py:1164(__init__)
#        13    0.000    0.000    0.000    0.000 __init__.py:117(getLevelName)
#         4    0.000    0.000    0.000    0.000 __init__.py:1170(append)
#         2    0.000    0.000    0.000    0.000 __init__.py:1181(setLoggerClass)
#         2    0.000    0.000    0.000    0.000 __init__.py:1194(getLoggerClass)
#         5    0.000    0.000    0.000    0.000 __init__.py:12(<listcomp>)
#        10    0.000    0.000    0.000    0.000 __init__.py:1216(getLogger)
#         1    0.000    0.000    0.000    0.000 __init__.py:1233(_initialize)
#        10    0.000    0.000    0.000    0.000 __init__.py:1267(_fixupParents)
#         1    0.000    0.000    0.000    0.000 __init__.py:1291(_fixupChildren)
#         5    0.000    0.000    0.000    0.000 __init__.py:13(<listcomp>)
#         1    0.000    0.000    0.068    0.068 __init__.py:13(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1304(_clear_cache)
#        10    0.000    0.000    0.000    0.000 __init__.py:1336(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:134(UnidentifiedImageError)
#         1    0.000    0.000    0.000    0.000 __init__.py:1349(setLevel)
#         1    0.000    0.000    0.000    0.000 __init__.py:137(dynamic_wildcard_import)
#        13    0.000    0.000    0.009    0.001 __init__.py:1380(warning)
#         1    0.000    0.000    0.001    0.001 __init__.py:14(<module>)
#         3    0.000    0.000    0.000    0.000 __init__.py:141(<module>)
#       821    0.001    0.000    0.001    0.000 __init__.py:1429(log)
#         1    0.000    0.000    0.000    0.000 __init__.py:146(<dictcomp>)
#        13    0.000    0.000    0.001    0.000 __init__.py:1476(makeRecord)
#        13    0.000    0.000    0.009    0.001 __init__.py:1491(_log)
#        92    0.003    0.000    3.350    0.036 __init__.py:15(<module>)
#        13    0.000    0.000    0.008    0.001 __init__.py:1516(handle)
#         3    0.000    0.000    0.000    0.000 __init__.py:1526(addHandler)
#        13    0.000    0.000    0.008    0.001 __init__.py:1570(callHandlers)
#        20    0.000    0.000    2.032    0.102 __init__.py:16(<module>)
#         2    0.000    0.000    0.000    0.000 __init__.py:1600(getEffectiveLevel)
#         1    0.000    0.000    0.000    0.000 __init__.py:161(_VerbosityFlag)
#       834    0.000    0.000    0.000    0.000 __init__.py:1614(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 __init__.py:164(__init__)
#         6    0.000    0.000    0.508    0.085 __init__.py:17(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:174(value)
#         1    0.000    0.000    0.000    0.000 __init__.py:179(_update_logging_levels)
#         9    0.000    0.000    0.441    0.049 __init__.py:18(<module>)
#        16    0.000    0.000    0.000    0.000 __init__.py:187(_checkLevel)
#        11    0.000    0.000    0.420    0.038 __init__.py:19(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:19(get_keras_submodule)
#        11    0.000    0.000    0.000    0.000 __init__.py:1928(getLogger)
#         3    0.000    0.000    0.033    0.011 __init__.py:2(<module>)
#        13    0.000    0.000    0.223    0.017 __init__.py:20(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:203(_LoggerLevelsFlag)
#         1    0.000    0.000    0.001    0.001 __init__.py:205(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:206(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:2073(createLock)
#         9    0.000    0.000    0.300    0.033 __init__.py:21(<module>)
#        21    0.000    0.000    0.000    0.000 __init__.py:212(_acquireLock)
#         4    0.000    0.000    0.041    0.010 __init__.py:22(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:220(value)
#        21    0.000    0.000    0.000    0.000 __init__.py:221(_releaseLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:225(_update_logger_levels)
#         1    0.000    0.000    0.004    0.004 __init__.py:23(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:232(_LoggerLevelsParser)
#         3    0.000    0.000    0.000    0.000 __init__.py:232(_register_at_fork_reinit_lock)
#         1    0.000    0.000    0.000    0.000 __init__.py:235(parse)
#         6    0.001    0.000    0.701    0.117 __init__.py:24(<module>)
#         2    0.001    0.000    1.359    0.679 __init__.py:25(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:251(_LoggerLevelsSerializer)
#         1    0.000    0.000    0.000    0.000 __init__.py:254(serialize)
#         1    0.000    0.000    0.000    0.000 __init__.py:258(<genexpr>)
#         2    0.000    0.000    0.015    0.007 __init__.py:26(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:261(_StderrthresholdFlag)
#         1    0.000    0.000    0.000    0.000 __init__.py:264(__init__)
#         1    0.000    0.000    0.222    0.222 __init__.py:27(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:274(load)
#         1    0.000    0.000    0.000    0.000 __init__.py:274(value)
#         2    0.000    0.000    0.003    0.002 __init__.py:28(<module>)
#        13    0.000    0.000    0.001    0.000 __init__.py:282(__init__)
#         1    0.000    0.000    0.086    0.086 __init__.py:295(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:299(loads)
#         1    0.000    0.000    0.039    0.039 __init__.py:3(<module>)
#         1    0.000    0.000    0.003    0.003 __init__.py:30(<module>)
#         1    0.000    0.000    0.071    0.071 __init__.py:31(<module>)
#       384    0.062    0.000    0.083    0.000 __init__.py:316(namedtuple)
#        42    0.000    0.000    0.000    0.000 __init__.py:32(keras_modules_injection)
#         3    0.000    0.000    0.022    0.007 __init__.py:33(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:33(_LazyLoader)
#         2    0.000    0.000    0.000    0.000 __init__.py:340(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:358(_FuncPtr)
#        13    0.000    0.000    0.000    0.000 __init__.py:360(getMessage)
#        12    0.000    0.000    0.000    0.000 __init__.py:37(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:374(__getattr__)
#         7    0.000    0.000    0.000    0.000 __init__.py:38(__getattr__)
#         2    0.000    0.000    0.000    0.000 __init__.py:381(__getitem__)
#      1700    0.000    0.000    0.000    0.000 __init__.py:388(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:39(<module>)
#       209    0.006    0.000    0.732    0.004 __init__.py:4(<module>)
#         2    0.000    0.000    0.000    0.000 __init__.py:403(_make)
#         4    0.000    0.000    0.114    0.028 __init__.py:41(<module>)
#         2    0.000    0.000    0.000    0.000 __init__.py:415(__init__)
#        13    0.000    0.000    0.000    0.000 __init__.py:418(usesTime)
#         2    0.000    0.000    0.000    0.000 __init__.py:42(__getattr__)
#      80/4    0.000    0.000    2.004    0.501 __init__.py:42(_load)
#        13    0.000    0.000    0.000    0.000 __init__.py:421(format)
#         1    0.000    0.000    0.000    0.000 __init__.py:43(<listcomp>)
#         1    0.000    0.000    0.007    0.007 __init__.py:45(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:46(deprecate)
#         1    0.000    0.000    0.000    0.000 __init__.py:47(create_string_buffer)
#        11    0.000    0.000    0.000    0.000 __init__.py:47(wrap)
#         2    0.000    0.000    0.000    0.000 __init__.py:49(<module>)
#      80/4    0.000    0.000    2.004    0.501 __init__.py:49(__getattr__)
#         1    0.000    0.000    0.000    0.000 __init__.py:49(check_compatibility)
#        96    0.002    0.000    0.007    0.000 __init__.py:5(<module>)
#         1    0.000    0.000    0.020    0.020 __init__.py:50(<module>)
#         2    0.000    0.000    0.000    0.000 __init__.py:502(__init__)
#         1    0.000    0.000    0.025    0.025 __init__.py:55(<module>)
#         3    0.000    0.000    0.001    0.000 __init__.py:57(<module>)
#        13    0.000    0.000    0.000    0.000 __init__.py:573(usesTime)
#        13    0.000    0.000    0.000    0.000 __init__.py:579(formatMessage)
#        13    0.000    0.000    0.000    0.000 __init__.py:595(format)
#         1    0.000    0.000    0.000    0.000 __init__.py:6(<listcomp>)
#         6    0.000    0.000    0.000    0.000 __init__.py:6(<module>)
#         3    0.000    0.000    0.000    0.000 __init__.py:60(ModProxy)
#        12    0.000    0.000    0.000    0.000 __init__.py:60(_forward_module)
#         1    0.000    0.000    0.022    0.022 __init__.py:61(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:664(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:665(<listcomp>)
#        21    0.001    0.000    0.009    0.000 __init__.py:7(<module>)
#         1    0.000    0.000    0.016    0.016 __init__.py:70(<module>)
#         3    0.000    0.000    0.000    0.000 __init__.py:71(<module>)
#        15    0.000    0.000    0.000    0.000 __init__.py:716(__init__)
#         1    0.000    0.000    0.002    0.002 __init__.py:72(<module>)
#        26    0.000    0.000    0.000    0.000 __init__.py:736(filter)
#         1    0.000    0.000    0.000    0.000 __init__.py:755(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:767(_running_from_pip_package)
#         5    0.000    0.000    0.000    0.000 __init__.py:769(<genexpr>)
#         1    0.000    0.000    0.066    0.066 __init__.py:78(<module>)
#         5    0.000    0.000    0.000    0.000 __init__.py:783(_addHandlerRef)
#         2    0.000    0.000    0.007    0.004 __init__.py:79(<module>)
#         8    0.000    0.000    0.100    0.013 __init__.py:8(<module>)
#         5    0.000    0.000    0.000    0.000 __init__.py:802(__init__)
#         3    0.000    0.000    0.005    0.002 __init__.py:81(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:816(PythonHandler)
#         1    0.000    0.000    0.000    0.000 __init__.py:819(__init__)
#         1    0.000    0.000    0.151    0.151 __init__.py:82(<module>)
#         3    0.000    0.000    0.000    0.000 __init__.py:831(createLock)
#        26    0.000    0.000    0.000    0.000 __init__.py:838(acquire)
#        26    0.000    0.000    0.000    0.000 __init__.py:845(release)
#        13    0.000    0.000    0.000    0.000 __init__.py:858(format)
#         1    0.000    0.000    0.132    0.132 __init__.py:86(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:86(reexport_tf_summary)
#        13    0.000    0.000    0.008    0.001 __init__.py:881(handle)
#         2    0.000    0.000    0.000    0.000 __init__.py:899(setFormatter)
#         2    0.000    0.000    0.000    0.000 __init__.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:90(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:954(ABSLHandler)
#         1    0.000    0.000    0.000    0.000 __init__.py:957(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:989(activate_python_handler)
#         2    0.000    0.000    0.000    0.000 __init__.py:991(__init__)
#         1    0.000    0.000    0.000    0.000 __version__.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 _appengine_environ.py:12(is_appengine_sandbox)
#         1    0.000    0.000    0.000    0.000 _appengine_environ.py:22(is_local_appengine)
#         1    0.000    0.000    0.000    0.000 _appengine_environ.py:28(is_prod_appengine)
#         1    0.000    0.000    0.000    0.000 _appengine_environ.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _appengine_environ.py:8(is_appengine)
#         8    0.000    0.000    0.000    0.000 _argument_parser.py:116(parse)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:150(ArgumentSerializer)
#        10    0.000    0.000    0.000    0.000 _argument_parser.py:153(serialize)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:158(NumericParser)
#         2    0.000    0.000    0.000    0.000 _argument_parser.py:164(is_outside_bounds)
#         2    0.000    0.000    0.000    0.000 _argument_parser.py:169(parse)
#         1    0.000    0.000    0.004    0.004 _argument_parser.py:19(<module>)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:202(FloatParser)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:243(IntegerParser)
#         2    0.000    0.000    0.000    0.000 _argument_parser.py:252(__init__)
#         2    0.000    0.000    0.000    0.000 _argument_parser.py:273(convert)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:294(BooleanParser)
#         9    0.000    0.000    0.000    0.000 _argument_parser.py:297(parse)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:322(EnumParser)
#         2    0.000    0.000    0.000    0.000 _argument_parser.py:34(_is_integer_type)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:373(EnumClassParser)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:40(_ArgumentParserCache)
#        21    0.000    0.000    0.000    0.000 _argument_parser.py:45(__call__)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:455(ListSerializer)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:465(EnumClassListSerializer)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:492(CsvListSerializer)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:517(EnumClassSerializer)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:534(BaseListParser)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:566(ListParser)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:597(WhitespaceSeparatedListParser)
#         1    0.000    0.000    0.000    0.000 _argument_parser.py:98(ArgumentParser)
#     47252    0.027    0.000    0.814    0.000 _asarray.py:14(asarray)
#     22289    0.013    0.000    0.029    0.000 _asarray.py:86(asanyarray)
#         1    0.000    0.000    0.000    0.000 _binary.py:15(<module>)
#         4    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#         1    0.000    0.000    0.000    0.000 _collections.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _collections.py:107(HTTPHeaderDict)
#         1    0.000    0.000    0.000    0.000 _collections.py:31(RecentlyUsedContainer)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:15(<module>)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:252(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:271(__subclasshook__)
#        78    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:349(__subclasshook__)
#        10    0.000    0.000    0.000    0.000 _collections_abc.py:367(__subclasshook__)
#       395    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:406(__subclasshook__)
#     48353    0.050    0.000    0.174    0.000 _collections_abc.py:657(get)
#     47260    0.100    0.000    0.297    0.000 _collections_abc.py:664(__contains__)
#     23825    0.025    0.000    0.039    0.000 _collections_abc.py:676(items)
#     23825    0.014    0.000    0.014    0.000 _collections_abc.py:698(__init__)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#     72229    0.076    0.000    0.273    0.000 _collections_abc.py:742(__iter__)
#        22    0.000    0.000    0.001    0.000 _defines.py:109(DEFINE_flag)
#         1    0.000    0.000    0.005    0.005 _defines.py:18(<module>)
#         2    0.000    0.000    0.000    0.000 _defines.py:257(disclaim_key_flags)
#         8    0.000    0.000    0.000    0.000 _defines.py:276(DEFINE_string)
#         9    0.000    0.000    0.000    0.000 _defines.py:297(DEFINE_boolean)
#         1    0.000    0.000    0.000    0.000 _defines.py:379(DEFINE_integer)
#         1    0.000    0.000    0.000    0.000 _defines.py:49(_register_bounds_validator_if_needed)
#         9    0.000    0.000    0.000    0.000 _defines.py:69(DEFINE)
#         1    0.000    0.000    0.000    0.000 _defines.py:854(DEFINE_alias)
#         1    0.000    0.000    0.000    0.000 _defines.py:880(_FlagAlias)
#         1    0.000    0.000    0.000    0.000 _defines.py:887(_parse_from_default)
#         1    0.000    0.000    0.000    0.000 _defines.py:899(value)
#         1    0.000    0.000    0.000    0.000 _enum_module.py:41(<module>)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:103(UnparsedFlagAccessError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:105(SAXNotRecognizedException)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:107(ValidationError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:111(FlagNameConflictsWithMethodError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:115(SAXNotSupportedException)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:125(SAXReaderNotAvailable)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:19(<module>)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:33(Error)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:37(CantOpenFlagFileError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:44(DuplicateFlagError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:46(SAXParseException)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:78(IllegalFlagValueError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:82(UnrecognizedFlagError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:9(SAXException)
#        19    0.000    0.000    0.000    0.000 _flag.py:116(value)
#        22    0.000    0.000    0.000    0.000 _flag.py:143(_get_parsed_value_as_string)
#        20    0.000    0.000    0.000    0.000 _flag.py:169(_parse)
#         1    0.000    0.000    0.001    0.001 _flag.py:19(<module>)
#        22    0.000    0.000    0.000    0.000 _flag.py:210(_set_default)
#        20    0.000    0.000    0.000    0.000 _flag.py:223(_parse_from_default)
#         1    0.000    0.000    0.000    0.000 _flag.py:307(BooleanFlag)
#         9    0.000    0.000    0.000    0.000 _flag.py:320(__init__)
#         1    0.000    0.000    0.000    0.000 _flag.py:326(EnumFlag)
#         1    0.000    0.000    0.000    0.000 _flag.py:345(EnumClassFlag)
#         1    0.000    0.000    0.000    0.000 _flag.py:35(Flag)
#         1    0.000    0.000    0.000    0.000 _flag.py:372(MultiFlag)
#         1    0.000    0.000    0.000    0.000 _flag.py:448(MultiEnumClassFlag)
#        22    0.000    0.000    0.000    0.000 _flag.py:81(__init__)
#        22    0.000    0.000    0.000    0.000 _flagvalues.py:1286(_check_method_name_conflicts)
#         1    0.000    0.000    0.000    0.000 _flagvalues.py:1311(FlagHolder)
#        22    0.000    0.000    0.000    0.000 _flagvalues.py:1341(__init__)
#        24    0.000    0.000    0.000    0.000 _flagvalues.py:148(_flags)
#        22    0.000    0.000    0.000    0.000 _flagvalues.py:151(flags_by_module_dict)
#        22    0.000    0.000    0.000    0.000 _flagvalues.py:160(flags_by_module_id_dict)
#        22    0.000    0.000    0.000    0.000 _flagvalues.py:178(register_flag_by_module)
#         1    0.000    0.000    0.000    0.000 _flagvalues.py:18(<module>)
#        22    0.000    0.000    0.000    0.000 _flagvalues.py:191(register_flag_by_module_id)
#        22    0.000    0.000    0.000    0.000 _flagvalues.py:414(__setitem__)
#         1    0.000    0.000    0.000    0.000 _flagvalues.py:468(__getitem__)
#         1    0.000    0.000    0.000    0.000 _flagvalues.py:48(FlagValues)
#         1    0.000    0.000    0.000    0.000 _flagvalues.py:607(__contains__)
#         2    0.000    0.000    0.000    0.000 _flagvalues.py:87(__init__)
#        22    0.000    0.000    0.000    0.000 _helpers.py:108(get_calling_module_object_and_name)
#        10    0.000    0.000    0.000    0.000 _helpers.py:135(str_or_unicode)
#         1    0.000    0.000    0.003    0.003 _helpers.py:15(<module>)
#         1    0.000    0.000    0.000    0.000 _helpers.py:80(_ModuleObjectAndName)
#        77    0.000    0.000    0.000    0.000 _helpers.py:90(get_module_object_and_name)
#         1    0.000    0.000    0.010    0.010 _internal_utils.py:9(<module>)
#         3    0.000    0.000    0.000    0.000 _methods.py:53(_any)
#         2    0.000    0.000    0.000    0.000 _methods.py:56(_all)
#         1    0.000    0.000    0.001    0.001 _monitor.py:30(__init__)
#         1    0.000    0.000    0.002    0.002 _output.py:15(<module>)
#         1    0.000    0.000    0.000    0.000 _output.py:25(Output)
#         1    0.000    0.000    0.000    0.000 _output.py:78(DirectoryOutput)
#         1    0.000    0.000    0.000    0.000 _parameterized_async.py:19(<module>)
#         1    0.000    0.000    0.003    0.003 _pretty_print_reporter.py:15(<module>)
#         1    0.000    0.000    0.000    0.000 _pretty_print_reporter.py:25(TextTestResult)
#         1    0.000    0.000    0.000    0.000 _pretty_print_reporter.py:71(TextTestRunner)
#         1    0.000    0.000    0.000    0.000 _sklearn.py:119(_ClassifierMixin)
#         1    0.000    0.000    0.000    0.000 _sklearn.py:124(_RegressorMixin)
#         1    0.000    0.000    0.000    0.000 _sklearn.py:129(_TransformerMixin)
#         1    0.000    0.000    0.000    0.000 _sklearn.py:133(NotFittedError)
#         1    0.000    0.000    0.000    0.000 _sklearn.py:16(<module>)
#         1    0.000    0.000    0.000    0.000 _sklearn.py:34(_BaseEstimator)
#         1    0.000    0.000    0.000    0.000 _tpu_estimator_embedding.py:15(<module>)
#         1    0.000    0.000    0.000    0.000 _tpu_estimator_embedding.py:182(EmbeddingConfigSpec)
#         1    0.000    0.000    0.000    0.000 _tpu_estimator_embedding.py:333(EmbeddingConfig)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:105(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:110(Sequence)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:121(Collection)
#        13    0.000    0.000    0.000    0.000 _typecheck.py:132(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:139(Tuple)
#         8    0.000    0.000    0.000    0.000 _typecheck.py:146(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:152(Mapping)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:165(Dict)
#   567/334    0.000    0.000    0.001    0.000 _typecheck.py:176(_replace_forward_references)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:18(<module>)
#   184/122    0.000    0.000    0.000    0.000 _typecheck.py:181(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _typecheck.py:186(register_type_abbreviation)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:212(Error)
#       119    0.000    0.000    0.000    0.000 _typecheck.py:216(accepts)
#       119    0.001    0.000    0.008    0.000 _typecheck.py:231(check_accepts)
#        66    0.000    0.000    0.005    0.000 _typecheck.py:251(new_f)
#       126    0.000    0.000    0.000    0.000 _typecheck.py:266(returns)
#       126    0.001    0.000    0.001    0.000 _typecheck.py:284(check_returns)
#        66    0.000    0.000    0.006    0.000 _typecheck.py:289(new_f)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:34(Type)
#       371    0.000    0.000    0.000    0.000 _typecheck.py:51(__init__)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:59(_SingleArgumentType)
#       287    0.000    0.000    0.000    0.000 _typecheck.py:62(__init__)
#       122    0.000    0.000    0.000    0.000 _typecheck.py:65(_type)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:71(_TwoArgumentType)
#        11    0.000    0.000    0.000    0.000 _typecheck.py:74(__init__)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:78(Union)
#      17/9    0.000    0.000    0.000    0.000 _typecheck.py:84(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:88(Optional)
#       122    0.000    0.000    0.000    0.000 _typecheck.py:94(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 _typecheck.py:99(List)
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:433(__enter__)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:438(__exit__)
#         1    0.000    0.000    0.000    0.000 _util.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _util.py:14(deferred_error)
#         1    0.000    0.000    0.000    0.000 _validators.py:107(SingleFlagValidator)
#         1    0.000    0.000    0.000    0.000 _validators.py:148(MultiFlagsValidator)
#         1    0.000    0.000    0.000    0.000 _validators.py:33(<module>)
#         1    0.000    0.000    0.000    0.000 _validators.py:45(Validator)
#         2    0.000    0.000    0.000    0.000 _version.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         1    0.000    0.000    0.000    0.000 _writer.py:19(<module>)
#         1    0.000    0.000    0.000    0.000 _writer.py:29(Writer)
#   556/555    0.001    0.000    0.012    0.000 abc.py:125(__new__)
#         5    0.000    0.000    0.000    0.000 abc.py:130(register)
#    238856    0.074    0.000    0.211    0.000 abc.py:137(__instancecheck__)
#  1145/278    0.000    0.000    0.002    0.000 abc.py:141(__subclasscheck__)
#       135    0.000    0.000    0.000    0.000 abc.py:7(abstractmethod)
#         1    0.000    0.000    0.000    0.000 absltest.py:1305(_AssertRaisesContext)
#         1    0.000    0.000    0.000    0.000 absltest.py:141(TempFileCleanup)
#         1    0.000    0.000    0.000    0.000 absltest.py:158(_get_default_test_random_seed)
#         1    0.000    0.000    0.000    0.000 absltest.py:169(get_default_test_srcdir)
#         1    0.000    0.000    0.001    0.001 absltest.py:175(get_default_test_tmpdir)
#         1    0.000    0.000    0.012    0.012 absltest.py:19(<module>)
#         1    0.000    0.000    0.000    0.000 absltest.py:2021(_SavedFlag)
#         1    0.000    0.000    0.000    0.000 absltest.py:2145(TestLoader)
#         1    0.000    0.000    0.000    0.000 absltest.py:268(_monkey_patch_test_result_for_unexpected_passes)
#         1    0.000    0.000    0.000    0.000 absltest.py:320(_TempDir)
#         1    0.000    0.000    0.000    0.000 absltest.py:401(_TempFile)
#         1    0.000    0.000    0.000    0.000 absltest.py:563(TestCase)
#         1    0.000    0.000    0.001    0.001 absolute_value.py:15(<module>)
#         1    0.000    0.000    0.000    0.000 absolute_value.py:33(AbsoluteValue)
#         1    0.000    0.000    0.275    0.275 activations.py:15(<module>)
#         6    0.000    0.000    0.000    0.000 activations.py:280(linear)
#         6    0.000    0.000    0.000    0.000 activations.py:310(get)
#         1    0.000    0.000    0.000    0.000 activity.py:142(_Lambda)
#         1    0.000    0.000    0.000    0.000 activity.py:150(_Comprehension)
#         1    0.000    0.000    0.000    0.000 activity.py:158(ActivityAnalyzer)
#         1    0.000    0.000    0.001    0.001 activity.py:18(<module>)
#         1    0.000    0.000    0.000    0.000 activity.py:36(Scope)
#         3    0.000    0.000    0.009    0.003 adadelta.py:16(<module>)
#         1    0.000    0.000    0.000    0.000 adadelta.py:25(AdadeltaOptimizer)
#         1    0.000    0.000    0.000    0.000 adadelta.py:28(AdadeltaOptimizer)
#         1    0.000    0.000    0.000    0.000 adadelta.py:31(Adadelta)
#         3    0.000    0.000    0.000    0.000 adagrad.py:16(<module>)
#         1    0.000    0.000    0.000    0.000 adagrad.py:29(AdagradOptimizer)
#         1    0.000    0.000    0.000    0.000 adagrad.py:31(AdagradOptimizer)
#         1    0.000    0.000    0.000    0.000 adagrad.py:37(Adagrad)
#         1    0.000    0.000    0.000    0.000 adagrad_da.py:15(<module>)
# ...
#       497    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       497    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__init_subclass__' of 'object' objects}
#         4    0.000    0.000    0.000    0.000 {method '__prepare__' of 'type' objects}
#       485    0.001    0.000    0.001    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       533    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#     75741    0.232    0.000    0.232    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'add' of 'google.protobuf.pyext._message.RepeatedCompositeContainer' objects}
#     96050    0.010    0.000    0.010    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#       178    0.000    0.000    0.000    0.000 {method 'append' of 'DescriptorSequence' objects}
#      2577    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        12    0.000    0.000    0.000    0.000 {method 'append' of 'google.protobuf.pyext._message.RepeatedScalarContainer' objects}
#   4073452    0.304    0.000    0.304    0.000 {method 'append' of 'list' objects}
#       333    0.026    0.000    0.026    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#       352    0.002    0.000    0.002    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'bind' of '_socket.socket' objects}
#     87270    0.007    0.000    0.007    0.000 {method 'bit_length' of 'int' objects}
#         4    0.000    0.000    0.000    0.000 {method 'capitalize' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'cast' of 'memoryview' objects}
#     22286    0.985    0.000    1.172    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#        31    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#       632    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#     69258    0.024    0.000    0.024    0.000 {method 'copy' of 'list' objects}
#        56    0.000    0.000    0.000    0.000 {method 'copy' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#       590    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#     49574    0.028    0.000    0.028    0.000 {method 'encode' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'end' of 're.Match' objects}
#      2542    0.002    0.000    0.002    0.000 {method 'endswith' of 'str' objects}
#       689    0.001    0.000    0.001    0.000 {method 'expandtabs' of 'str' objects}
#       135    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#       131    0.000    0.000    0.000    0.000 {method 'extend' of 'google.protobuf.pyext._message.RepeatedScalarContainer' objects}
#     19149    0.006    0.000    0.007    0.000 {method 'extend' of 'list' objects}
#      1596    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#        37    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'findall' of 're.Pattern' objects}
#       107    0.000    0.000    0.000    0.000 {method 'finditer' of 're.Pattern' objects}
#      8835    0.012    0.000    0.015    0.000 {method 'format' of 'str' objects}
#        27    0.000    0.000    0.000    0.000 {method 'get' of 'DescriptorMapping' objects}
#    140296    0.032    0.000    0.032    0.000 {method 'get' of 'dict' objects}
#       275    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#    128644    0.020    0.000    0.020    0.000 {method 'getrandbits' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getter' of 'property' objects}
#      1915    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#        14    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        85    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'tuple' objects}
#     22318    0.004    0.000    0.004    0.000 {method 'insert' of 'list' objects}
#     16013    0.002    0.000    0.002    0.000 {method 'isidentifier' of 'str' objects}
#       484    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#       127    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.generic' objects}
#        98    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#     94310    0.021    0.000    0.021    0.000 {method 'items' of 'dict' objects}
#        96    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
# 151018/150950    0.023    0.000    0.024    0.000 {method 'join' of 'str' objects}
#     50043    0.005    0.000    0.005    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#      7347    0.001    0.000    0.001    0.000 {method 'lower' of 'str' objects}
#     14416    0.002    0.000    0.002    0.000 {method 'lstrip' of 'str' objects}
#      1868    0.003    0.000    0.003    0.000 {method 'match' of 're.Pattern' objects}
#        33    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#         3    0.000    0.000    0.000    0.000 {method 'newbyteorder' of 'numpy.generic' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pack' of 'Struct' objects}
#      3770    0.001    0.000    0.001    0.000 {method 'partition' of 'str' objects}
#      1493    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#     49516    0.016    0.000    0.016    0.000 {method 'pop' of 'list' objects}
#       275    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#       131    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    1.575    0.787    1.575    0.787 {method 'read' of '_io.BufferedReader' objects}
#      2444    0.098    0.000    0.098    0.000 {method 'read' of '_io.FileIO' objects}
#         2    0.000    0.000    0.000    0.000 {method 'read' of '_io.TextIOWrapper' objects}
#     22339    0.160    0.000    0.160    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       485    0.001    0.000    0.001    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#       533    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#     48142    0.009    0.000    0.009    0.000 {method 'release' of '_thread.lock' objects}
#    335568    0.205    0.000    0.205    0.000 {method 'remove' of 'list' objects}
#        57    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       681    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#     22292    0.035    0.000    0.035    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        56    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#     16359    0.004    0.000    0.004    0.000 {method 'rpartition' of 'str' objects}
#      4892    0.003    0.000    0.003    0.000 {method 'rsplit' of 'str' objects}
#     56090    0.005    0.000    0.005    0.000 {method 'rstrip' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'seed' of 'numpy.random.mtrand.RandomState' objects}
#        98    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#       106    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#       241    0.002    0.000    0.002    0.000 {method 'shuffle' of 'numpy.random.mtrand.RandomState' objects}
#      1101    0.018    0.000    0.036    0.000 {method 'sort' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'split' of 'bytes' objects}
#         4    0.000    0.000    0.000    0.000 {method 'split' of 're.Pattern' objects}
#     23464    0.016    0.000    0.016    0.000 {method 'split' of 'str' objects}
#      1200    0.003    0.000    0.003    0.000 {method 'splitlines' of 'str' objects}
#       298    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#     43568    0.007    0.000    0.007    0.000 {method 'startswith' of 'str' objects}
#      1547    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#       499    0.001    0.000    0.001    0.000 {method 'sub' of 're.Pattern' objects}
#   272/270    0.000    0.000    0.001    0.000 {method 'throw' of 'generator' objects}
#         3    0.000    0.000    0.000    0.000 {method 'tobytes' of 'numpy.generic' objects}
#         8    0.000    0.000    0.000    0.000 {method 'tolist' of 'memoryview' objects}
#        18    0.000    0.000    0.000    0.000 {method 'tostring' of 'numpy.ndarray' objects}
#       201    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'translate' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'union' of 'frozenset' objects}
#         2    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#      3154    0.003    0.000    0.003    0.000 {method 'update' of 'dict' objects}
#       109    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#       234    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       438    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#      2513    0.001    0.000    0.001    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.BufferedWriter' objects}
#         1    0.000    0.000    0.000    0.000 {method 'writerow' of '_csv.writer' objects}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-7f0ffaa72166> in <module>
#     161 import cProfile
#     162
# --> 163 cProfile.run('run()')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\cProfile.py in run(statement, filename, sort)
#      14
#      15 def run(statement, filename=None, sort=-1):
# ---> 16     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#      17
#      18 def runctx(statement, globals, locals, filename=None, sort=-1):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\profile.py in run(self, statement, filename, sort)
#      51         prof = self.profiler()
#      52         try:
# ---> 53             prof.run(statement)
#      54         except SystemExit:
#      55             pass
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\cProfile.py in run(self, cmd)
#      93         import __main__
#      94         dict = __main__.__dict__
# ---> 95         return self.runctx(cmd, dict, dict)
#      96
#      97     def runctx(self, cmd, globals, locals):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\cProfile.py in runctx(self, cmd, globals, locals)
#      98         self.enable()
#      99         try:
# --> 100             exec(cmd, globals, locals)
#     101         finally:
#     102             self.disable()
#
# <string> in <module>
#
# <ipython-input-1-7f0ffaa72166> in run()
#     118         for episode in t:
#     119             # Generate data from the environment
# --> 120             trajectories, payoffs = env.run(is_training=True)
#     121             payoff_avg.append(payoffs[0])
#     122
#
# d:\Projects\rlcard\rlcard\envs\tractor.py in run(self, is_training, debug)
#      61                     print()
#      62             else:
# ---> 63                 action = self.agents[player_id].step(state)
#      64
#      65             # Environment steps
#
# d:\Projects\rlcard\rlcard\agents\dqn_agent.py in step(self, state)
#     142         else:
#     143             # A = self.predict(state['obs'])
# --> 144             A = self.predict(state)
#     145
#     146             action = np.random.choice(np.arange(len(A)), p=A)
#
# d:\Projects\rlcard\rlcard\agents\dqn_agent.py in predict(self, state)
#     176         A = np.ones(self.action_num, dtype=float) * epsilon / len(state['legal_actions'])
#     177
# --> 178         q_values = self.q_estimator.predict(self.sess, np.expand_dims(state['obs'], 0))[0]
#     179
#     180         best_action = state['legal_actions'][0]
#
# d:\Projects\rlcard\rlcard\agents\dqn_agent.py in predict(self, sess, s)
#     324           action values.
#     325         '''
# --> 326         return sess.run(self.predictions, { self.X_pl: s, self.is_train:False})
#     327
#     328     def update(self, sess, s, a, y):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
